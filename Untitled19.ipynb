# %% [markdown]
# <a href="https://colab.research.google.com/github/25c022/class01/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: 움직이는 로봇 청소기에서 정사각형을 그리며 그림으로 출력해

import matplotlib.pyplot as plt
import time
from IPython import display

def draw_square(robot_position, size=1):
    """Draws a square centered around the robot's position."""
    x, y = robot_position
    # Define the four points of the square
    square_x = [x - size/2, x + size/2, x + size/2, x - size/2, x - size/2]
    square_y = [y - size/2, y - size/2, y + size/2, y + size/2, y - size/2]
    return square_x, square_y

# Initialize robot position
robot_x, robot_y = 0, 0
step_size = 1

# Create the plot
plt.figure(figsize=(6, 6))
ax = plt.gca()
ax.set_xlim([-2, 2])
ax.set_ylim([-2, 2])
ax.set_aspect('equal', adjustable='box')
ax.set_title("Moving Robot Vacuum Drawing a Square")

# Simulate the robot movement and drawing
path_x = [robot_x]
path_y = [robot_y]

# Move right
for _ in range(1):
    robot_x += step_size
    path_x.append(robot_x)
    path_y.append(robot_y)
    square_x, square_y = draw_square((robot_x, robot_y))
    plt.plot(square_x, square_y, 'b-', alpha=0.2) # Draw the square boundary
    plt.plot(path_x, path_y, 'ro-') # Draw the robot's path
    display.clear_output(wait=True)
    display.display(plt.gcf())
    time.sleep(0.5)

# Move up
for _ in range(1):
    robot_y += step_size
    path_x.append(robot_x)
    path_y.append(robot_y)
    square_x, square_y = draw_square((robot_x, robot_y))
    plt.plot(square_x, square_y, 'b-', alpha=0.2) # Draw the square boundary
    plt.plot(path_x, path_y, 'ro-') # Draw the robot's path
    display.clear_output(wait=True)
    display.display(plt.gcf())
    time.sleep(0.5)

# Move left
for _ in range(1):
    robot_x -= step_size
    path_x.append(robot_x)
    path_y.append(robot_y)
    square_x, square_y = draw_square((robot_x, robot_y))
    plt.plot(square_x, square_y, 'b-', alpha=0.2) # Draw the square boundary
    plt.plot(path_x, path_y, 'ro-') # Draw the robot's path
    display.clear_output(wait=True)
    display.display(plt.gcf())
    time.sleep(0.5)

# Move down
for _ in range(1):
    robot_y -= step_size
    path_x.append(robot_x)
    path_y.append(robot_y)
    square_x, square_y = draw_square((robot_x, robot_y))
    plt.plot(square_x, square_y, 'b-', alpha=0.2) # Draw the square boundary
    plt.plot(path_x, path_y, 'ro-') # Draw the robot's path
    display.clear_output(wait=True)
    display.display(plt.gcf())
    time.sleep(0.5)

# Final plot with the completed square
square_x, square_y = draw_square((0.5, 0.5), size=2) # Draw the final complete square boundary
plt.plot(square_x, square_y, 'k-', linewidth=2)
plt.plot(path_x, path_y, 'ro-')
display.clear_output(wait=True)
display.display(plt.gcf())
plt.show()
